# %% [markdown]
# <a href="https://colab.research.google.com/github/Faudzan10/AVD_1/blob/main/Checkpoint_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #BUSINESS UNDERSTANDING

# %% [markdown]
# ##**BUSSINESS OBJECTIVE**

# %% [markdown]
# Tujuan utama proyek ini adalah untuk memahami tren pasar dan preferensi pelanggan dalam industri laptop guna mendukung pengembangan produk yang lebih sesuai dengan kebutuhan pengguna. Analisis ini mencakup identifikasi pola harga, spesifikasi yang paling diminati, serta faktor yang mempengaruhi keputusan pembelian pelanggan. Dengan pemahaman ini, perusahaan dapat meningkatkan strategi pemasaran, mengoptimalkan stok produk, serta menawarkan rekomendasi laptop yang lebih tepat sasaran berdasarkan data pelanggan.

# %% [markdown]
# ##**Assess Sitution**

# %% [markdown]
# Industri laptop terus berkembang dengan persaingan yang ketat dan perubahan teknologi yang cepat. Konsumen memiliki berbagai preferensi terkait merek, spesifikasi hardware, dan harga yang sesuai dengan kebutuhan mereka. Data menunjukkan bahwa faktor seperti performa prosesor, kapasitas RAM, jenis penyimpanan, dan kartu grafis memainkan peran penting dalam keputusan pembelian. Oleh karena itu, analisis segmentasi pelanggan menjadi krusial untuk memahami pola pembelian dan mengantisipasi tren pasar yang terus berubah.

# %% [markdown]
# ##**Data Mining Goals**

# %% [markdown]
# Mengidentifikasi segmen pelanggan berdasarkan preferensi spesifikasi laptop seperti prosesor, RAM, penyimpanan, dan kartu grafis,Menganalisis hubungan antara harga dan spesifikasi laptop untuk menemukan pola yang mempengaruhi keputusan pembelian,Memprediksi tren pasar dengan memahami pergeseran preferensi pelanggan terhadap teknologi terbaru,Mengembangkan model rekomendasi laptop berdasarkan analisis data untuk meningkatkan pengalaman pelanggan dalam memilih produk.

# %% [markdown]
# ##**Project Plan**

# %% [markdown]
# Pengumpulan Data: Menggunakan dataset laptop yang mencakup informasi spesifikasi, harga, dan ulasan pelangga.
# -Exploratory Data Analysis: Mengidentifikasi pola dalam data, seperti distribusi harga, spesifikasi yang paling diminati, serta korelasi antara fitur dan rating.
# -Verify Data Quality
# Mengecek data yang hilang (missing values) dan mengisinya jika diperlukan.
# Memeriksa inkonsistensi data seperti duplikasi atau format yang tidak sesuai.
# -Describe Data
# Menganalisis distribusi data seperti rentang harga, spesifikasi yang umum, dan jumlah ulasan.
# Menampilkan statistik deskriptif seperti mean, median, dan modus dari setiap fitur.

# %% [markdown]
# #**Data Understanding**

# %%
# Sumber Data: https://www.kaggle.com/datasets/siddiquifaiznaeem/laptop-sales-price-prediction-dataset-2024

print("Dataset diambil dari: https://www.kaggle.com/datasets/siddiquifaiznaeem/laptop-sales-price-prediction-dataset-2024")
# Out:
# Dataset diambil dari: https://www.kaggle.com/datasets/siddiquifaiznaeem/laptop-sales-price-prediction-dataset-2024

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/laptop_cleaned2.csv"

df = pd.read_csv(file_path)

# %% [markdown]
# ##**DATASET**

# %%
df
# Out:
#       Unnamed: 0                                               Name    Brand  \
# 0              0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1              1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2              2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3              3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4              4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
# ...          ...                                                ...      ...
# 1015        1015              MSI Creator Z17 HX Studio A13V Laptop      MSI
# 1016        1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      MSI
# 1017        1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus
# 1019        1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell
#
# ...

# %% [markdown]
# ##**PENGECEKAN STRUKTUR DATA**

# %%
print("Jika ingin menampilkan Beberapa Row Data:")
df.head(3)
# Out:
# Jika ingin menampilkan Beberapa Row Data:
#    Unnamed: 0                                               Name   Brand  \
# 0           0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...      HP
# 1           1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...  Lenovo
# 2           2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...      HP
#
#    Price  Rating Processor_brand Processor_name Processor_variant  \
# 0  50399    4.30             AMD    AMD Ryzen 5             5600H
# 1  26690    4.45             AMD    AMD Ryzen 3             7320U
# 2  37012    4.65           Intel  Intel Core i3             1215U
#
#    Processor_gen  Core_per_processor  ...        Graphics_name  \
# 0            5.0                 6.0  ...  AMD Radeon RX 6500M
# 1            7.0                 4.0  ...  AMD Radeon Graphics
# 2           12.0                 6.0  ...   Intel UHD Graphics
#
#    Graphics_brand  Graphics_GB  Graphics_integreted  Display_size_inches  \
# ...

# %%
print("\nJika ingin menampilkan Keseluruhan Data:")
df
# Out:
# Jika ingin menampilkan Keseluruhan Data:
#       Unnamed: 0                                               Name    Brand  \
# 0              0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1              1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2              2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3              3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4              4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
# ...          ...                                                ...      ...
# 1015        1015              MSI Creator Z17 HX Studio A13V Laptop      MSI
# 1016        1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      MSI
# 1017        1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus
# 1019        1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell
#
# ...

# %%
print("\nMenampilkan 5 baris pertama dengan df.head():")
df.head()
# Out:
# Menampilkan 5 baris pertama dengan df.head():
#    Unnamed: 0                                               Name    Brand  \
# 0           0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1           1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2           2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3           3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4           4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
#
#    Price  Rating Processor_brand Processor_name Processor_variant  \
# 0  50399    4.30             AMD    AMD Ryzen 5             5600H
# 1  26690    4.45             AMD    AMD Ryzen 3             7320U
# 2  37012    4.65           Intel  Intel Core i3             1215U
# 3  69990    4.75           Intel  Intel Core i5             1240P
# 4  23990    4.25           Intel  Intel Core i3            1115G4
#
#    Processor_gen  Core_per_processor  ...           Graphics_name  \
# ...

# %%
print("\nMenampilkan 5 baris terakhir dengan df.tail():")
df.tail()
# Out:
# Menampilkan 5 baris terakhir dengan df.tail():
#       Unnamed: 0                                               Name Brand  \
# 1015        1015              MSI Creator Z17 HX Studio A13V Laptop   MSI
# 1016        1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...   MSI
# 1017        1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...    HP
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...  Asus
# 1019        1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...  Dell
#
#        Price  Rating Processor_brand Processor_name Processor_variant  \
# 1015  247999    4.45           Intel  Intel Core i9            13900H
# 1016  292990    4.20           Intel  Intel Core i9            13900H
# 1017   58800    4.40             AMD    AMD Ryzen 5             5600H
# 1018   54999    4.25             AMD    AMD Ryzen 5             7530U
# 1019   94490    4.05           Intel  Intel Core i5             1335U
#
# ...

# %% [markdown]
# ##**MENAMPILKAN TIPE DATA SETIAP KOLOM**

# %%
print("\nMenampilkan tipe data setiap kolom dengan df.dtypes:")
df.dtypes
# Out:
# Menampilkan tipe data setiap kolom dengan df.dtypes:
# Unnamed: 0                  int64
# Name                       object
# Brand                      object
# Price                       int64
# Rating                    float64
# Processor_brand            object
# Processor_name             object
# Processor_variant          object
# Processor_gen             float64
# Core_per_processor        float64
# Total_processor           float64
# Execution_units           float64
# Low_Power_Cores           float64
# Energy_Efficient_Units      int64
# Threads                   float64
# RAM_GB                      int64
# RAM_type                   object
# Storage_capacity_GB         int64
# Storage_type               object
# Graphics_name              object
# Graphics_brand             object
# Graphics_GB               float64
# Graphics_integreted        object
# Display_size_inches       float64
# Horizontal_pixel            int64
# Vertical_pixel              int64
# ...

# %% [markdown]
# ##**JUMLAH  BARIS DAN KOLOM**

# %%
print("\nMenampilkan jumlah baris dan kolom dengan df.shape:")
print(df.shape)
# Out:
# Menampilkan jumlah baris dan kolom dengan df.shape:
# (1020, 29)

# %% [markdown]
# ##**Statistik Deskriptif**

# %%
df.describe()
# Out:
#         Unnamed: 0          Price       Rating  Processor_gen  \
# count  1020.000000    1020.000000  1020.000000     891.000000
# mean    509.500000   82063.474510     4.373676      10.450056
# std     294.592939   66502.150607     0.233295       2.966579
# min       0.000000    8000.000000     3.950000       1.000000
# 25%     254.750000   43990.000000     4.200000       7.000000
# 50%     509.500000   63689.500000     4.350000      12.000000
# 75%     764.250000   94990.000000     4.550000      13.000000
# max    1019.000000  599990.000000     4.750000      14.000000
#
#        Core_per_processor  Total_processor  Execution_units  Low_Power_Cores  \
# count         1008.000000       573.000000       573.000000      1020.000000
# mean             8.572421         3.926702         6.998255         0.086275
# std              4.375012         1.954429         2.680217         0.406531
# min              2.000000         1.000000         4.000000         0.000000
# ...

# %% [markdown]
# ##**Analisis Korelasi**

# %%
kolom_tertentu = "Brand"
if kolom_tertentu in df.columns:
    print(f"\nMenghitung jumlah kemunculan nilai unik dalam kolom '{kolom_tertentu}' dengan df['{kolom_tertentu}'].value_counts():")
    print(df[kolom_tertentu].value_counts())
else:
    print(f"\nKolom '{kolom_tertentu}' tidak ditemukan dalam dataset.")

print("\nMenghitung rata-rata dengan df.mean():")
print(df.mean(numeric_only=True))

print("\nMenghitung median dengan df.median():")
print(df.median(numeric_only=True))

print("\nMenghitung standar deviasi dengan df.std():")
print(df.std(numeric_only=True))

print("\nMenghitung korelasi antar kolom numerik dengan df.corr():")
print(df.corr(numeric_only=True))
# Out:
# Menghitung jumlah kemunculan nilai unik dalam kolom 'Brand' dengan df['Brand'].value_counts():
# Brand
# Lenovo       217
# HP           213
# Asus         157
# Dell         116
# MSI           97
# Acer          69
# Samsung       32
# Apple         20
# Infinix       20
# Chuwi          8
# Zebronics      7
# Microsoft      7
# LG             7
# Xiaomi         6
# Gigabyte       6
# Honor          6
# Avita          6
# Ultimus        5
# Wings          3
# Fujitsu        3
# Primebook      3
# Huawei         2
# AXL            2
# Jio            1
# Ninkear        1
# ASUS           1
# Walker         1
# iBall          1
# Tecno          1
# Razer          1
# Colorful       1
# Name: count, dtype: int64
#
# Menghitung rata-rata dengan df.mean():
# Unnamed: 0                  509.500000
# Price                     82063.474510
# Rating                        4.373676
# Processor_gen                10.450056
# Core_per_processor            8.572421
# ...

# %% [markdown]
# #**Data Preparation**

# %%
-
# Out:
# Dataset diambil dari: https://www.kaggle.com/datasets/siddiquifaiznaeem/laptop-sales-price-prediction-dataset-2024

# %%
import pandas as pd

# %%
file_path = "/content/laptop_cleaned2.csv"

df = pd.read_csv(file_path)

# %%
df
# Out:
#       Unnamed: 0                                               Name    Brand  \
# 0              0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1              1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2              2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3              3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4              4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
# ...          ...                                                ...      ...
# 1015        1015              MSI Creator Z17 HX Studio A13V Laptop      MSI
# 1016        1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      MSI
# 1017        1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus
# 1019        1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell
#
# ...

# %% [markdown]
# ##**Mencari nilai yang Missing,Duplicate,Outliers,Inconsistent Values**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Unnamed: 0                 0.000000
# Name                       0.000000
# Brand                      0.000000
# Price                      0.000000
# Rating                     0.000000
# Processor_brand            0.000000
# Processor_name             0.000000
# Processor_variant          2.352941
# Processor_gen             12.647059
# Core_per_processor         1.176471
# Total_processor           43.823529
# Execution_units           43.823529
# Low_Power_Cores            0.000000
# Energy_Efficient_Units     0.000000
# Threads                    4.705882
# RAM_GB                     0.000000
# RAM_type                   2.156863
# Storage_capacity_GB        0.000000
# Storage_type               0.000000
# Graphics_name              0.196078
# Graphics_brand             0.196078
# Graphics_GB               63.921569
# Graphics_integreted        0.196078
# Display_size_inches        0.000000
# Horizontal_pixel           0.000000
# Vertical_pixel             0.000000
# ...

# %% [markdown]
# ###**Missing Values**

# %%
df[df['Processor_variant'].isnull()]
# Out:
#      Unnamed: 0                                               Name      Brand  \
# 13           13  Apple MacBook Air 2020 MGND3HN Laptop (Apple M...      Apple
# 17           17  Apple MacBook Air 2024 Laptop (Apple M3/ 8GB/ ...      Apple
# 23           23  Apple MacBook Air 2022 Laptop (Apple M2/ 8GB/ ...      Apple
# 73           73  Apple MacBook Air 2024 MRYN3HN/A Laptop (Apple...      Apple
# 83           83  Apple MacBook Pro 16 2023 Laptop (Apple M3 Max...      Apple
# 100         100  Apple MacBook Air 15 2024 MRYR3HN/A Laptop (Ap...      Apple
# 116         116  Apple MacBook Pro 14 2023 Laptop (Apple M3 Pro...      Apple
# 138         138  Apple MacBook Air 2022 Laptop (Apple M2/ 8GB/ ...      Apple
# 154         154  Lenovo Ideapad Slim 3 Chrome 14M868 82XJ002RHA...     Lenovo
# 163         163  Apple MacBook Pro 14 2023 Laptop (Apple M3/ 8G...      Apple
# 202         202  Apple MacBook Air 2024 MRXW3HN/A Laptop (Apple...      Apple
# ...

# %%
df[df['Processor_gen'].isnull()]
# Out:
#       Unnamed: 0                                               Name    Brand  \
# 13            13  Apple MacBook Air 2020 MGND3HN Laptop (Apple M...    Apple
# 17            17  Apple MacBook Air 2024 Laptop (Apple M3/ 8GB/ ...    Apple
# 23            23  Apple MacBook Air 2022 Laptop (Apple M2/ 8GB/ ...    Apple
# 24            24  Samsung Galaxy Book 4 NP750XGK-KS2IN Laptop (I...  Samsung
# 26            26  Samsung Galaxy Book 4 Ultra Laptop (Intel Core...  Samsung
# ...          ...                                                ...      ...
# 902          902  HP Chromebook 15a-nb0002TU Laptop ( Intel Core...       HP
# 952          952  Acer Aspire 3 A315-510P Laptop (Intel Core i3 ...     Acer
# 982          982  AXL Vayu Book LAP01 Laptop (Celeron N4020/ 4GB...      AXL
# 984          984  AXL Vayu Book LAP02 Laptop (Celeron N4020/ 4GB...      AXL
# 1008        1008  HP 14s-dr3003TU 832T7PA Laptop (Pentium Silver...       HP
#
# ...

# %%
df[df['Core_per_processor'].isnull()]
# Out:
#      Unnamed: 0                                               Name      Brand  \
# 80           80  MSI Titan 18 HX Gaming Laptop (14th Gen Core i...        MSI
# 140         140  Samsung Galaxy Book2 15 Laptop (12th Gen Core ...    Samsung
# 194         194  Samsung Galaxy Book 4 Edge Laptop (Snapdragon ...    Samsung
# 253         253  Lenovo LOQ 15IRH8 82XV00BRIN 2023 Gaming Lapto...     Lenovo
# 501         501  ‎Lenovo V15 G2 IJL 82QYA00HIN Laptop (Celeron ...     Lenovo
# 531         531  Samsung Galaxy Book 3 Laptop (13th Gen Core i5...    Samsung
# 548         548  Lenovo V14 82KA00G8IH Laptop (11th Gen Core i3...     Lenovo
# 583         583  Microsoft Surface Pro X 1876 Ultrabook (Micros...  Microsoft
# 586         586  Samsung Galaxy Book Flex Alpha 2-in-1 Laptop (...    Samsung
# 648         648  Huawei Qingyun L540 Laptop (Kirin 9006C/ 16GB/...     Huawei
# 778         778  Asus TUF Gaming F15 90NR0GW1-M00F00 Laptop (12...       Asus
# ...

# %%
df[df['Total_processor'].isnull()]
# Out:
#       Unnamed: 0                                               Name    Brand  \
# 0              0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1              1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 4              4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
# 10            10  Wings Nuvobook V1 Laptop (11th Gen Core i5/ 8G...    Wings
# 11            11  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...   Lenovo
# ...          ...                                                ...      ...
# 1004        1004  HP Victus 16-d0302TX Gaming Laptop (11th Gen C...       HP
# 1008        1008  HP 14s-dr3003TU 832T7PA Laptop (Pentium Silver...       HP
# 1012        1012  Infinix INBook X2 Slim Series XL23 Laptop (11t...  Infinix
# 1017        1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus
#
# ...

# %%
 df[df['Execution_units'].isnull()]
# Out:
#       Unnamed: 0                                               Name    Brand  \
# 0              0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1              1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 4              4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
# 10            10  Wings Nuvobook V1 Laptop (11th Gen Core i5/ 8G...    Wings
# 11            11  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...   Lenovo
# ...          ...                                                ...      ...
# 1004        1004  HP Victus 16-d0302TX Gaming Laptop (11th Gen C...       HP
# 1008        1008  HP 14s-dr3003TU 832T7PA Laptop (Pentium Silver...       HP
# 1012        1012  Infinix INBook X2 Slim Series XL23 Laptop (11t...  Infinix
# 1017        1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus
#
# ...

# %%
  df[df['Threads'].isnull()]
# Out:
#       Unnamed: 0                                               Name  \
# 13            13  Apple MacBook Air 2020 MGND3HN Laptop (Apple M...
# 17            17  Apple MacBook Air 2024 Laptop (Apple M3/ 8GB/ ...
# 23            23  Apple MacBook Air 2022 Laptop (Apple M2/ 8GB/ ...
# 45            45  Dell G15-5530 15 2023 Gaming Laptop (13th Gen ...
# 73            73  Apple MacBook Air 2024 MRYN3HN/A Laptop (Apple...
# 80            80  MSI Titan 18 HX Gaming Laptop (14th Gen Core i...
# 83            83  Apple MacBook Pro 16 2023 Laptop (Apple M3 Max...
# 100          100  Apple MacBook Air 15 2024 MRYR3HN/A Laptop (Ap...
# 116          116  Apple MacBook Pro 14 2023 Laptop (Apple M3 Pro...
# 129          129  Dell G15-5530 Gaming 2023 Laptop (13th Gen Cor...
# 138          138  Apple MacBook Air 2022 Laptop (Apple M2/ 8GB/ ...
# 140          140  Samsung Galaxy Book2 15 Laptop (12th Gen Core ...
# 142          142  iBall Excelance CompBook Laptop (AQC/ 2GB/ 32G...
# ...

# %%
df[df['RAM_type'].isnull()]
# Out:
#      Unnamed: 0                                               Name     Brand  \
# 17           17  Apple MacBook Air 2024 Laptop (Apple M3/ 8GB/ ...     Apple
# 83           83  Apple MacBook Pro 16 2023 Laptop (Apple M3 Max...     Apple
# 116         116  Apple MacBook Pro 14 2023 Laptop (Apple M3 Pro...     Apple
# 163         163  Apple MacBook Pro 14 2023 Laptop (Apple M3/ 8G...     Apple
# 175         175  Asus Zenbook 14X OLED 2023 UX5401ZA-KM541WS La...      Asus
# 202         202  Apple MacBook Air 2024 MRXW3HN/A Laptop (Apple...     Apple
# 203         203  Apple MacBook Air 15 2024 Laptop (Apple M3/ 16...     Apple
# 294         294  Apple MacBook Pro 2022 Laptop (Apple M2/ 8GB/ ...     Apple
# 295         295  Asus VivoBook 15 X515MA-BR011W Laptop (Celeron...      Asus
# 347         347  Apple MacBook Pro 16 2023 Laptop (Apple M3 Pro...     Apple
# 348         348  Apple MacBook Pro 14 2023 Laptop (Apple M3/ 8G...     Apple
# ...

# %%
 df[df['Graphics_name'].isnull()]
# Out:
#      Unnamed: 0                                               Name   Brand  \
# 648         648  Huawei Qingyun L540 Laptop (Kirin 9006C/ 16GB/...  Huawei
# 998         998  Dell Vostro 5630 Laptop (13th Gen Core i7/ 16G...    Dell
#
#      Price  Rating Processor_brand                Processor_name  \
# 648  81999     4.3       HiSilicon  HiSilicon  Kirin 9006C 9006C
# 998  94990     4.6           Intel                 Intel Core i7
#
#     Processor_variant  Processor_gen  Core_per_processor  ...  Graphics_name  \
# 648             9006C            NaN                 NaN  ...            NaN
# 998             1355U           13.0                10.0  ...            NaN
#
#      Graphics_brand  Graphics_GB  Graphics_integreted  Display_size_inches  \
# 648             NaN          NaN                  NaN                 14.0
# 998             NaN          NaN                  NaN                 16.0
#
#      Horizontal_pixel Vertical_pixel     ppi Touch_screen Operating_system
# ...

# %%
 df[df['Graphics_brand'].isnull()]
# Out:
#      Unnamed: 0                                               Name   Brand  \
# 648         648  Huawei Qingyun L540 Laptop (Kirin 9006C/ 16GB/...  Huawei
# 998         998  Dell Vostro 5630 Laptop (13th Gen Core i7/ 16G...    Dell
#
#      Price  Rating Processor_brand                Processor_name  \
# 648  81999     4.3       HiSilicon  HiSilicon  Kirin 9006C 9006C
# 998  94990     4.6           Intel                 Intel Core i7
#
#     Processor_variant  Processor_gen  Core_per_processor  ...  Graphics_name  \
# 648             9006C            NaN                 NaN  ...            NaN
# 998             1355U           13.0                10.0  ...            NaN
#
#      Graphics_brand  Graphics_GB  Graphics_integreted  Display_size_inches  \
# 648             NaN          NaN                  NaN                 14.0
# 998             NaN          NaN                  NaN                 16.0
#
#      Horizontal_pixel Vertical_pixel     ppi Touch_screen Operating_system
# ...

# %%
 df[df['Graphics_GB'].isnull()]
# Out:
#       Unnamed: 0                                               Name    Brand  \
# 1              1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2              2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3              3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4              4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
# 5              5  Samsung Galaxy Book2 NP550XED-KA1IN 15 Laptop ...  Samsung
# ...          ...                                                ...      ...
# 1012        1012  Infinix INBook X2 Slim Series XL23 Laptop (11t...  Infinix
# 1013        1013  Dell Inspiron 3530 IN3530NM1NN001ORS1 Laptop (...     Dell
# 1014        1014  Dell Inspiron 5430 IN5430YXVW9M01ORS1 Laptop (...     Dell
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus
# 1019        1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell
#
# ...

# %%
df[df['Graphics_integreted'].isnull()]
# Out:
#      Unnamed: 0                                               Name   Brand  \
# 648         648  Huawei Qingyun L540 Laptop (Kirin 9006C/ 16GB/...  Huawei
# 998         998  Dell Vostro 5630 Laptop (13th Gen Core i7/ 16G...    Dell
#
#      Price  Rating Processor_brand                Processor_name  \
# 648  81999     4.3       HiSilicon  HiSilicon  Kirin 9006C 9006C
# 998  94990     4.6           Intel                 Intel Core i7
#
#     Processor_variant  Processor_gen  Core_per_processor  ...  Graphics_name  \
# 648             9006C            NaN                 NaN  ...            NaN
# 998             1355U           13.0                10.0  ...            NaN
#
#      Graphics_brand  Graphics_GB  Graphics_integreted  Display_size_inches  \
# 648             NaN          NaN                  NaN                 14.0
# 998             NaN          NaN                  NaN                 16.0
#
#      Horizontal_pixel Vertical_pixel     ppi Touch_screen Operating_system
# ...

# %% [markdown]
# ###**Duplicate**

# %% [markdown]
# Data tidak ada yang duplicate

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Brand, Price, Rating, Processor_brand, Processor_name, Processor_variant, Processor_gen, Core_per_processor, Total_processor, Execution_units, Low_Power_Cores, Energy_Efficient_Units, Threads, RAM_GB, RAM_type, Storage_capacity_GB, Storage_type, Graphics_name, Graphics_brand, Graphics_GB, Graphics_integreted, Display_size_inches, Horizontal_pixel, Vertical_pixel, ppi, Touch_screen, Operating_system]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# ###**Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                   Persentase Outliers
# Unnamed: 0                         0.000000
# Price                              7.647059
# Rating                             0.000000
# Processor_gen                      0.000000
# Core_per_processor                 2.647059
# Total_processor                    0.000000
# Execution_units                    2.352941
# Low_Power_Cores                    4.313725
# Energy_Efficient_Units             4.313725
# Threads                            2.254902
# RAM_GB                             6.764706
# Storage_capacity_GB               31.176471
# Graphics_GB                        1.078431
# Display_size_inches                1.176471
# Horizontal_pixel                  24.509804
# Vertical_pixel                    24.313725
# ppi                               12.941176

# %% [markdown]
# ###**Incosistent Value**

# %%
df
# Out:
#       Unnamed: 0                                               Name    Brand  \
# 0              0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1              1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2              2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3              3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4              4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
# ...          ...                                                ...      ...
# 1015        1015              MSI Creator Z17 HX Studio A13V Laptop      MSI
# 1016        1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      MSI
# 1017        1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus
# 1019        1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell
#
# ...

# %% [markdown]
# #

# %% [markdown]
# ##**Melakukan Penanganan pada Missing Values,Duplicate,Outliers,Inconsistens Values**

# %% [markdown]
# ###**Missing Values**

# %% [markdown]
# Dengan cara diimputasi dan di data saya tidak ada yang >= 70%

# %%
df['Processor_variant'].dropna().describe()
# Out:
# count       996
# unique      125
# top       1235U
# freq         60
# Name: Processor_variant, dtype: object

# %%
df['Processor_gen'].dropna().describe()
# Out:
# count    891.000000
# mean      10.450056
# std        2.966579
# min        1.000000
# 25%        7.000000
# 50%       12.000000
# 75%       13.000000
# max       14.000000
# Name: Processor_gen, dtype: float64

# %%
df['Core_per_processor'].dropna().describe()
# Out:
# count    1008.000000
# mean        8.572421
# std         4.375012
# min         2.000000
# 25%         6.000000
# 50%         8.000000
# 75%        10.000000
# max        24.000000
# Name: Core_per_processor, dtype: float64

# %%
df['Total_processor'].dropna().describe()
# Out:
# count    573.000000
# mean       3.926702
# std        1.954429
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        6.000000
# max       12.000000
# Name: Total_processor, dtype: float64

# %%
df['Execution_units'].dropna().describe()
# Out:
# count    573.000000
# mean       6.998255
# std        2.680217
# min        4.000000
# 25%        4.000000
# 50%        8.000000
# 75%        8.000000
# max       16.000000
# Name: Execution_units, dtype: float64

# %%
df['Threads'].dropna().describe()
# Out:
# count    972.000000
# mean      12.817901
# std        5.677459
# min        2.000000
# 25%        8.000000
# 50%       12.000000
# 75%       16.000000
# max       32.000000
# Name: Threads, dtype: float64

# %%
df['RAM_type'].dropna().describe()
# Out:
# count      998
# unique      12
# top       DDR4
# freq       522
# Name: RAM_type, dtype: object

# %%
df['Graphics_name'].dropna().describe()
# Out:
# count                       1018
# unique                       136
# top       Intel Iris Xe Graphics
# freq                         100
# Name: Graphics_name, dtype: object

# %%
df['Graphics_brand'].dropna().describe()
# Out:
# count      1018
# unique        7
# top       Intel
# freq        486
# Name: Graphics_brand, dtype: object

# %%
df['Graphics_GB'].dropna().describe()
# Out:
# count    368.000000
# mean       5.940217
# std        2.667130
# min        2.000000
# 25%        4.000000
# 50%        6.000000
# 75%        8.000000
# max       16.000000
# Name: Graphics_GB, dtype: float64

# %%
df['Graphics_integreted'].dropna().describe()
# Out:
# count      1018
# unique        2
# top       False
# freq        772
# Name: Graphics_integreted, dtype: object

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#                         Null Ratio %
# Unnamed: 0                  0.000000
# Name                        0.000000
# Brand                       0.000000
# Price                       0.000000
# Rating                      0.000000
# Processor_brand             0.000000
# Processor_name              0.000000
# Processor_variant           2.352941
# Processor_gen              12.647059
# Core_per_processor          1.176471
# Total_processor            43.823529
# Execution_units            43.823529
# Low_Power_Cores             0.000000
# Energy_Efficient_Units      0.000000
# Threads                     4.705882
# RAM_GB                      0.000000
# RAM_type                    2.156863
# Storage_capacity_GB         0.000000
# Storage_type                0.000000
# Graphics_name               0.196078
# Graphics_brand              0.196078
# Graphics_GB                63.921569
# Graphics_integreted         0.196078
# Display_size_inches         0.000000
# ...

# %% [markdown]
# ###**Duplicate**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Brand, Price, Rating, Processor_brand, Processor_name, Processor_variant, Processor_gen, Core_per_processor, Total_processor, Execution_units, Low_Power_Cores, Energy_Efficient_Units, Threads, RAM_GB, RAM_type, Storage_capacity_GB, Storage_type, Graphics_name, Graphics_brand, Graphics_GB, Graphics_integreted, Display_size_inches, Horizontal_pixel, Vertical_pixel, ppi, Touch_screen, Operating_system]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# tidak ada data yang terduplikasi

# %% [markdown]
# ###**Incosistent Value**

# %%
df
# Out:
#                                                    Name    Brand   Price  \
# 0     HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP   50399
# 1     Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo   26690
# 2     HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP   37012
# 3     Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung   69990
# 4     Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno   23990
# ...                                                 ...      ...     ...
# 1015              MSI Creator Z17 HX Studio A13V Laptop      MSI  247999
# 1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      MSI  292990
# 1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP   58800
# 1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus   54999
# 1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell   94490
#
#       Rating Processor_brand Processor_name Processor_variant  Processor_gen  \
# ...

# %%
df["Brand"] = df["Brand"].str.strip().str.title()

# %%
df
# Out:
#                                                    Name    Brand   Price  \
# 0     HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       Hp   50399
# 1     Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo   26690
# 2     HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       Hp   37012
# 3     Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung   69990
# 4     Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno   23990
# ...                                                 ...      ...     ...
# 1015              MSI Creator Z17 HX Studio A13V Laptop      Msi  247999
# 1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      Msi  292990
# 1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       Hp   58800
# 1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus   54999
# 1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell   94490
#
#       Rating Processor_brand Processor_name Processor_variant  Processor_gen  \
# ...

# %% [markdown]
# ###**Outliers**

# %%
df
# Out:
#       Unnamed: 0                                               Name    Brand  \
# 0              0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1              1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2              2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3              3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4              4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
# ...          ...                                                ...      ...
# 1015        1015              MSI Creator Z17 HX Studio A13V Laptop      MSI
# 1016        1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      MSI
# 1017        1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus
# 1019        1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell
#
# ...

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)

# %%
columns_to_impute = ["Price", "Core_per_processor", "Execution_units", "Low_Power_Cores",
                     "Energy_Efficient_Units", "Threads", "RAM_GB", "Storage_capacity_GB",
                     "Graphics_GB", "Display_size_inches", "Horizontal_pixel", "Vertical_pixel", "ppi"]

for col in columns_to_impute:
    if col in df.columns:
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

# %%
for col in columns_to_impute:
    if col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Perbaikan: Sesuaikan nilai outlier dengan batas bawah & atas
        df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# Melakukan pengecekan ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)

# %% [markdown]
# ##**Construct Data**

# %%
df["Cooling_System"] = df["Name"].apply(lambda x: "Advanced Cooling" if "Gaming" in x or "RTX" in x else "Standard Cooling")

print(df[["Name", "Cooling_System"]].head())
# Out:
#                                                 Name    Cooling_System
# 0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  Advanced Cooling
# 1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...  Standard Cooling
# 2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  Standard Cooling
# 3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Standard Cooling
# 4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  Standard Cooling

# %%
df
# Out:
#                                                    Name    Brand   Price  \
# 0     HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP   50399
# 1     Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo   26690
# 2     HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP   37012
# 3     Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung   69990
# 4     Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno   23990
# ...                                                 ...      ...     ...
# 1015              MSI Creator Z17 HX Studio A13V Laptop      MSI  247999
# 1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      MSI  292990
# 1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP   58800
# 1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus   54999
# 1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell   94490
#
#       Rating Processor_brand Processor_name Processor_variant  Processor_gen  \
# ...

# %% [markdown]
# ##**Data Reduction**

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df
# Out:
#       Unnamed: 0                                               Name    Brand  \
# 0              0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1              1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2              2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3              3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4              4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
# ...          ...                                                ...      ...
# 1015        1015              MSI Creator Z17 HX Studio A13V Laptop      MSI
# 1016        1016  MSI Stealth 16 Mercedes AMG Motorsport A13V Ga...      MSI
# 1017        1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP
# 1018        1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus
# 1019        1019  Dell Inspiron 7630 IC7630GHHRH001ORS1 2 in 1 L...     Dell
#
# ...

# %% [markdown]
# #**VISUALISASI DATA**

# %%
# Sumber Data: https://www.kaggle.com/datasets/siddiquifaiznaeem/laptop-sales-price-prediction-dataset-2024

print("Dataset diambil dari: https://www.kaggle.com/datasets/siddiquifaiznaeem/laptop-sales-price-prediction-dataset-2024")
# Out:
# Dataset diambil dari: https://www.kaggle.com/datasets/siddiquifaiznaeem/laptop-sales-price-prediction-dataset-2024

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "/content/laptop_cleaned2.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Unnamed: 0                                               Name    Brand  \
# 0           0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1           1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2           2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3           3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4           4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
#
#    Price  Rating Processor_brand Processor_name Processor_variant  \
# 0  50399    4.30             AMD    AMD Ryzen 5             5600H
# 1  26690    4.45             AMD    AMD Ryzen 3             7320U
# 2  37012    4.65           Intel  Intel Core i3             1215U
# 3  69990    4.75           Intel  Intel Core i5             1240P
# 4  23990    4.25           Intel  Intel Core i3            1115G4
#
#    Processor_gen  Core_per_processor  ...           Graphics_name  \
# ...

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['price'], bins=30, kde=True, color='royalblue')
plt.title('Distribusi Harga Laptop', fontsize=14)
plt.xlabel('Harga (Rp)', fontsize=12)
plt.ylabel('Jumlah Laptop', fontsize=12)
plt.show()

# %% [markdown]
# **INSIGHT**
#
# -Mayoritas laptop berharga di bawah 100 juta, dengan sedikit model di segmen premium.
#
# -Distribusi condong ke kanan, menunjukkan lebih sedikit laptop mahal.
#
# -Pasar lebih tertarik pada laptop mid-range dibanding high-end.
#
#
#
# **TINDAKAN**
#
# -Fokus stok di rentang harga populer.
#
# -Gunakan strategi pemasaran eksklusif untuk laptop premium.
#
# -Tawarkan promo untuk model high-end agar lebih menarik

# %%
plt.figure(figsize=(6, 6))
storage_counts = df['storage_type'].value_counts()
plt.pie(storage_counts, labels=storage_counts.index, autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'gold'])
plt.title('Distribusi Jenis Penyimpanan Laptop', fontsize=14)
plt.show()

# %% [markdown]
# **INSIGHT**
#
# -SSD mendominasi (97.9%), menunjukkan bahwa mayoritas laptop kini menggunakan SSD.
#
# -HDD & NVMe SSD sangat minim, menunjukkan pergeseran teknologi ke SSD standar.
#
# **TINDAKAN**
#
# -Fokus produksi & stok laptop dengan SSD.
#
# -Kurangi varian HDD kecuali untuk segmen tertentu.
#
# -Promosikan NVMe SSD untuk pasar high-performance.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y=df['brand'], order=df['brand'].value_counts().index, palette="viridis")
plt.title('Popularitas Merek Laptop', fontsize=14)
plt.xlabel('Jumlah Laptop', fontsize=12)
plt.ylabel('Merek', fontsize=12)
plt.show()
# Out:
# <ipython-input-29-56459abdd95a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['brand'], order=df['brand'].value_counts().index, palette="viridis")

# %% [markdown]
# **INSIGHT**
#
# -Lenovo, HP, Asus, dan Dell adalah merek laptop paling populer.
#
# -Merek seperti Acer, MSI, dan Samsung masih memiliki pangsa pasar yang cukup besar.
#
# -Merek lain memiliki jumlah produk yang jauh lebih sedikit, menunjukkan dominasi merek-merek besar.
#
# **TINDAKAN**
#
# -Fokus pemasaran pada merek-merek populer untuk meningkatkan penjualan.
#
# -Analisis faktor yang membuat merek top lebih diminati.
#
# -Eksplorasi strategi pemasaran untuk merek dengan pangsa lebih kecil.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='ram_gb', y='price', hue='brand', alpha=0.7, palette='coolwarm')
plt.title('Hubungan Kapasitas RAM dan Harga Laptop', fontsize=14)
plt.xlabel('Kapasitas RAM (GB)', fontsize=12)
plt.ylabel('Harga (Rp)', fontsize=12)
plt.legend(title='Brand', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# **INSIGHT**
#
# -Harga laptop cenderung meningkat dengan kapasitas RAM yang lebih besar.
#
# -Rentang harga sangat bervariasi, bahkan untuk kapasitas RAM yang sama.
#
# -Beberapa merek memiliki laptop dengan harga premium meskipun kapasitas RAM tidak jauh berbeda.
#
# **TINDAKAN**
#
# -Tawarkan laptop dengan RAM yang sesuai dengan kebutuhan pelanggan dan anggaran mereka.
#
# -Edukasi pelanggan bahwa harga juga dipengaruhi oleh spesifikasi lain, bukan hanya RAM.
#
# -Lakukan analisis lebih lanjut terkait merek yang menawarkan harga lebih tinggi untuk RAM tertentu.

# %%
print(df[['processor_gen', 'price']].dropna().head())
print(df['processor_gen'].unique())
print(df['price'].describe())
# Out:
#    processor_gen  price
# 0            5.0  50399
# 1            7.0  26690
# 2           12.0  37012
# 3           12.0  69990
# 4           11.0  23990
# [ 5.  7. 12. 11. 14. nan 13.  6.  3.  8. 10.  1.  9.  4.]
# count      1020.000000
# mean      82063.474510
# std       66502.150607
# min        8000.000000
# 25%       43990.000000
# 50%       63689.500000
# 75%       94990.000000
# max      599990.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=avg_price_per_gen.index, y=avg_price_per_gen.values, marker="o", linewidth=2, color="b")
plt.xlabel("Generasi Prosesor")
plt.ylabel("Harga Rata-rata (Rp)")
plt.title("Tren Harga Rata-rata Berdasarkan Generasi Prosesor")
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# %% [markdown]
# **INSIGHT**
#
# -Harga rata-rata laptop cenderung meningkat seiring dengan generasi prosesor yang lebih baru.
#
# -Beberapa generasi menunjukkan fluktuasi harga yang signifikan, misalnya generasi ke-9 mengalami lonjakan harga yang tinggi.
#
# -Generasi terbaru (ke-14) memiliki harga rata-rata paling mahal.
#
# **TINDAKAN**
#
# -Rekomendasikan prosesor sesuai kebutuhan pengguna, tidak selalu harus generasi terbaru jika anggaran terbatas.
#
# -Perhatikan generasi yang punya value for money terbaik (misalnya, performa tinggi tetapi harga masih terjangkau).
#
# -Analisis lebih lanjut apakah lonjakan harga disebabkan oleh teknologi baru atau faktor lainnya.

# %%
df_corr = df[['price', 'ram_gb', 'storage_capacity_gb', 'graphics_gb']].copy()
df_corr = df_corr.apply(pd.to_numeric, errors='coerce')

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Korelasi Spesifikasi Laptop dengan Harga', fontsize=14)
plt.show()

# %% [markdown]
# **INSIGHT**
#
# Dari heatmap korelasi:
#
# -Graphics Card (graphics_gb) memiliki korelasi tertinggi dengan harga (0.82) → Laptop dengan GPU yang lebih baik cenderung lebih mahal.
#
# -RAM (ram_gb) juga cukup berpengaruh (0.76) → Semakin besar RAM, semakin mahal harga laptopnya.
#
# -Storage (storage_capacity_gb) memiliki korelasi paling rendah dengan harga (0.67) → Penyimpanan besar tidak selalu berarti harga lebih mahal.
#
# **TINDAKNA**
#
# -Jika mencari laptop untuk gaming atau desain grafis, prioritaskan GPU karena dampaknya besar terhadap harga dan performa.
#
# -Jika anggaran terbatas, menambah RAM mungkin lebih menguntungkan dibandingkan meningkatkan kapasitas storage.
#
# -Lakukan analisis tambahan apakah ada brand tertentu yang menawarkan spesifikasi tinggi dengan harga lebih terjangkau.
